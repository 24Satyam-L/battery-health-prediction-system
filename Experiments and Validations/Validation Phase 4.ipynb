# %%
import pandas as pd

Battery_Summary =pd.read_csv(rf"C:\Projects\Battery Engineering\Summary Files\Final_Results_Phase_3.csv")

Cycle_Summary = pd.read_csv(rf"C:\Projects\Battery Engineering\Summary Files\All_Batteries_Overall_Summary.csv")

# %%
Cycle_Summary.head()
# Out:
#    Cycle Pair Battery ID  Charge_Ah  Discharge_Ah  Initial Discharge_Ah  \
# 0           1      B0047   1.542413      1.544693              1.544693
# 1           2      B0047   1.538655      1.528466              1.544693
# 2           3      B0047   1.522346      1.507771              1.544693
# 3           4      B0047   1.504613      1.491364              1.544693
# 4           5      B0047   1.487749      1.473101              1.544693
#
#    Charge_Wh  Discharge_Wh  Charge Duration_Sec  Discharge Duration_Sec  \
# 0   6.421848      5.371312            10800.719                5572.860
# 1   6.381547      5.305905            10799.500                5513.375
# 2   6.322247      5.230876            10805.188                5438.672
# 3   6.256810      5.167553            10803.203                5380.141
# 4   6.190991      5.100052            10801.578                5314.516
#
#    Average_Charge_Voltage  ...  Ambient Temperature  Max Charge Temperature  \
# ...

# %%
Cycle_Summary = Cycle_Summary[Cycle_Summary['Battery ID'] == 'B0032']
Battery_Summary = Battery_Summary[Battery_Summary['Battery'] == 'B0032']

# %%
import sys
import os
module_path = os.path.abspath(rf"C:\Projects\Battery Engineering\Decison Rules")
sys.path.append(module_path)
import Thermal_Rules as Th
import Battery_State_builder as BSB
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
State = BSB.build_battery_state(Battery_Summary, Cycle_Summary)

# %%
print(State)
# Out:
# {'battery_id': 11    B0032
# Name: Battery, dtype: object, 'segment': 11    No Spike
# Name: Segment, dtype: object, 'model_type': 11    Linear Regression
# Name: Model, dtype: object, 'degradation_slope': 11   -0.330696
# Name: Slope, dtype: float64, 'remaining_cycles': 11    204.0
# ...

# %%
for i in range(State["cycle_count"]):
    print(Th.detect_Overheat(State["max_temp_series"][i]))

#print(Th.detect_Temperature_Rise(State["max_temp_series"][0],State["ambient_temp_series"][0]))
#print(Th.detect_Thermal_Stress(State["max_temp_series"],State["ambient_temp_series"]))
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
flag = Th.evaluate_thermal(State)
print(flag)
# Out:
# {'overheat': [True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True], 'temp_rise': [True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True], 'thermal_stress': 1.0}

# %%
print(Th.summarize_thermal(flag))
# Out:
# frequent_overheating
